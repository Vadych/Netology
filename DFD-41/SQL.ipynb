# %%
import pandas as pd

# %%
CONNECTION_STRING = 'postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db'

# %%
QUERY_COUNTRY_LANGUAGE = """
SELECT *
FROM country_language
"""

# %%
df_language = pd.read_sql(QUERY_COUNTRY_LANGUAGE, CONNECTION_STRING)
df_language.head()
# Out:
#   country_code    language  is_official  percentage
# 0          AFG      Pashto         True        52.4
# 1          NLD       Dutch         True        95.6
# 2          ANT  Papiamento         True        86.2
# 3          ALB   Albaniana         True        97.9
# 4          DZA      Arabic         True        86.0

# %%
QUERY_COUNTRY = """
SELECT *
FROM country
"""

# %%
df_country = pd.read_sql(QUERY_COUNTRY, CONNECTION_STRING)
df_country.head()
# Out:
#   code                  name      continent                     region  \
# 0  AFG           Afghanistan           Asia  Southern and Central Asia
# 1  NLD           Netherlands         Europe             Western Europe
# 2  ANT  Netherlands Antilles  North America                  Caribbean
# 3  ALB               Albania         Europe            Southern Europe
# 4  DZA               Algeria         Africa            Northern Africa
#
#    surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0      652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 2         800.0         NaN      217000             74.7    1941.0       NaN
# 3       28748.0      1912.0     3401200             71.6    3205.0    2500.0
# 4     2381740.0      1962.0    31471000             69.7   49982.0   46966.0
#
#               local_name                               government_form  \
# ...

# %%
QUERY_MAIN_LANGUAGE = """
SELECT *
FROM country c
INNER JOIN country_language l
ON c.code = l.country_code
WHERE l.is_official = TRUE
ORDER BY c.name, l.percentage DESC
"""

# %%
df_main_language = pd.read_sql(QUERY_MAIN_LANGUAGE, CONNECTION_STRING)
df_main_language.head()
# Out:
#   code            name continent                     region  surface_area  \
# 0  AFG     Afghanistan      Asia  Southern and Central Asia      652090.0
# 1  AFG     Afghanistan      Asia  Southern and Central Asia      652090.0
# 2  ALB         Albania    Europe            Southern Europe       28748.0
# 3  DZA         Algeria    Africa            Northern Africa     2381740.0
# 4  ASM  American Samoa   Oceania                  Polynesia         199.0
#
#    indep_year  population  life_expectancy      gnp  gnp_old  \
# 0      1919.0    22720000             45.9   5976.0      NaN
# 1      1919.0    22720000             45.9   5976.0      NaN
# 2      1912.0     3401200             71.6   3205.0   2500.0
# 3      1962.0    31471000             69.7  49982.0  46966.0
# 4         NaN       68000             75.1    334.0      NaN
#
#               local_name  government_form         head_of_state  capital  \
# 0  Afganistan/Afqanestan  Islamic Emirate         Mohammad Omar      1.0
# ...

# %% [markdown]
# Задание со звездочкой

# %%
df_star = df_country.merge(df_language[df_language['is_official']], 
                           left_on='code', right_on='country_code', how='left')
df_star
# Out:
#     code                                          name      continent  \
# 0    AFG                                   Afghanistan           Asia
# 1    AFG                                   Afghanistan           Asia
# 2    NLD                                   Netherlands         Europe
# 3    ANT                          Netherlands Antilles  North America
# 4    ANT                          Netherlands Antilles  North America
# ..   ...                                           ...            ...
# 282  IOT                British Indian Ocean Territory         Africa
# 283  SGS  South Georgia and the South Sandwich Islands     Antarctica
# 284  HMD             Heard Island and McDonald Islands     Antarctica
# 285  ATF                   French Southern territories     Antarctica
# 286  UMI          United States Minor Outlying Islands        Oceania
#
#                         region  surface_area  indep_year  population  \
# ...
