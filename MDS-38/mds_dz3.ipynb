# %% [markdown]
# # Домашнее задание "Продвинутая линейная алгебра".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Дан объект в $2D$ пространстве

# %%
import numpy as np
import matplotlib.pyplot as plt

A = [
[-100, -100, 1],
[-100, 100, 1],
[100, 100, 1],
[0, 0, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# При помощи линейных отображений:
# - Уменьшить объект в два раза

# %%
def mapping(M, vec, label):
    M_map = M @ vec.T
    plt.plot(vec[:, 0], vec[:, 1], color = 'blue', label = 'Исходная')
    plt.plot(M_map.T[:, 0], M_map.T[:, 1], color = 'red', label = label)
    plt.legend()
    plt.ylim([-200, 200])
    plt.xlim([-200, 200]) 
    ax = plt.gca()
    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# %%
M1 = np.eye(3) * 0.5
mapping(M1, A, 'Уменьшенная')

# %% [markdown]
# - Повернуть на 130 градусов

# %%
angle = 130 / 180 * np.pi
sin_a = np.sin(angle)
cos_a = np.cos(angle)
M2 = np.array([[cos_a, sin_a, 0], [-sin_a, cos_a, 0], [0, 0, 1]])
mapping(M2, A, 'Повернутая')

# %% [markdown]
# - Отразить объект относительно прямой y=x (поможет матрица `[[0, 1, 0], [1, 0, 0], [0, 0, 1]]`)

# %%
M3 = np.array([[0, 1, 0], [1, 0, 0], [0, 0, 1]])
mapping(M3 @ M1, A, 'Отраженная') # Применил масштаб, что бы не сливалось

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Найдите спектральное разложение матрицы:
# ```
# m = np.array([[1, 2],
#               [2, 3]])
# print(m)
# ```

# %%
m = np.array([[1, 2],
              [2, 3]])

# %%
eig_val, S = np.linalg.eig()
D = np.diag(eig_val)

# %%
# Проверка
S @ D @ S.T
# Out:
# array([[1., 2.],
#        [2., 3.]])
