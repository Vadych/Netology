# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"

# %% [markdown]
# ## Обязательная часть

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на **поиске** по сайту [habr.com](https://habr.com/ru/search/).
# Функция в качестве параметра должна принимать **список** запросов для поиска (например, `['python', 'анализ данных']`) и на основе материалов, попавших в результаты поиска по **каждому** запросу, возвращать датафрейм вида:
#
# ```
# <дата> - <заголовок> - <ссылка на материал>
# ```
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %% [markdown]
# ## Дополнительная часть (необязательная)

# %% [markdown]
# Функция из обязательной части задания должна быть расширена следующим образом:
# - кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента `4` необходимо получить материалы с первых 4 страниц результатов;
# - в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# ```
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>
# ```

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from pandas.core.common import flatten

# %%
url = 'https://habr.com'

# %%
def page_url(page):
    """Возвращает url страницы с номером page"""
    return url + f'/ru/search/page{page}/'

# %%
def get_habr_page_link(query, page):
    """Возвращает ссылки со страницы по заданному запросу"""
    res = requests.get(
        page_url(page),
        params={'q': query}
    )
    if res.status_code != 200:
        return {}
    links = BeautifulSoup(res.text).find_all('a', class_='tm-title__link')
    return {link['href'] for link in links}

# %%
def get_query_links(query, pages):
    """Возвращает все ссылки с pages страниц по запросу query"""
    return set(flatten(
        [get_habr_page_link(query, page) for page in range(1, pages+1)]
        ))

# %%
def parse_page(link):
    """Парсит статью по конкретной ссылке"""
    page_url = url + link
    res = requests.get(page_url)
    if res.status_code != 200:
        return {
            'link': page_url,
            'title': '!!! ОШИБКА !!!',
            'text': 'Ошибка доступа к странице'
        }
    try:
        page = BeautifulSoup(res.text)
        title = page.find('h1', class_='tm-title tm-title_h1').span.text
        date = page.find('span', class_='tm-article-datetime-published').time['title']
        text = page.find('div', class_='article-formatted-body').text
        like = int(page.find('span', class_='tm-votes-meter__value').text)
    except Exception as err:
        return {
            'link': page_url,
            'title': '!!! ОШИБКА !!!',
            'text': 'Ошибка парсинга страницы\n' + str(err)
        }
    return {
        'link': page_url,
        'text': text,
        'title': title,
        'date': date,
        'like': like
    }

# %%
def get_pages_links(queries, pages):
    """Получает все ссылки по запросам queries глубиной pages страниц"""
    links = set()
    links.update(
        *[get_query_links(query, pages) for query in queries]
    )
    return links

# %%
def get_habr_pages(queries, pages):
    """Формирует необходимый DataFrame"""
    links = get_pages_links(queries, pages)
    df = pd.DataFrame()
    for link in links:
        df = pd.concat(
            [df, pd.DataFrame([parse_page(link)])]
            )
    return df.reset_index(drop=True)

# %%
habr_df = get_habr_pages(['python', 'clojure'], 2)
habr_df
# Out:
#                                     link  \
# 0   https://habr.com/ru/articles/196418/
# 1   https://habr.com/ru/articles/774918/
# 2   https://habr.com/ru/articles/775440/
# 3       https://habr.com/ru/news/766124/
# 4   https://habr.com/ru/articles/549362/
# ..                                   ...
# 70  https://habr.com/ru/articles/339628/
# 71  https://habr.com/ru/articles/137608/
# 72      https://habr.com/ru/news/775270/
# 73  https://habr.com/ru/articles/247889/
# 74  https://habr.com/ru/articles/775898/
#
#                                                  text  \
# 0   Мы сделали это.\r\nРоссийский проект CodeNotes...
# 1   Привет, Хабр! Аргентум на связи, сегодня мы бу...
# 2   В наше время автоматизация стала ключевым факт...
# 3   JetBrain совместно с Python Software Foundatio...
# 4   Всем привет!\n\r\nЯ сделал перевод и набил суб...
# ..                                                ...
# 70  \nОбъединяем Websockets, Lisp и функциональное...
# 71                          Ошибка доступа к странице
# 72  Исследователь из Массачусетского технологическ...
# 73   В последнее время определенную известность по...
# 74  ВведениеВ мире разработки программного обеспеч...
#
#                                                 title               date  like
# 0             CodeNotes — победитель Clojure Cup 2013  2013-10-04, 21:16  68.0
# 1              Змеиная наука: Химия в Python, часть 1  2023-11-19, 14:05   8.0
# 2   Внедрение Автоматизации в Проект с Python: Шаг...  2023-11-21, 17:13   2.0
# 3   JetBrains и Python Software Foundation рассказ...  2023-10-09, 08:39   8.0
# 4   Effective Programs (10 Years of Clojure) — Ric...  2021-03-28, 15:19   4.0
# ..                                                ...                ...   ...
# 70  Объединяем Websockets, Lisp и функциональное п...  2017-10-08, 23:18   7.0
# 71                                     !!! ОШИБКА !!!                NaN   NaN
# 72  Исследование: ChatGPT работает лучше на Julia,...  2023-11-21, 10:27   0.0
# 73    Clojure — трансдьюсеры, редьюсеры и прочая муть  2015-01-19, 07:28  37.0
# 74  Создание фреймворка автоматизации на Python с ...  2023-11-23, 13:18   0.0
#
# [75 rows x 5 columns]

# %%
habr_df[habr_df['title'].str.contains('ОШИБКА')]
# Out:
#                                                  link  \
# 17               https://habr.com/ru/articles/104185/
# 27               https://habr.com/ru/articles/102197/
# 48  https://habr.com/ru/companies/epam_systems/new...
# 51  https://habr.com/ru/companies/raiffeisenbank/n...
# 71               https://habr.com/ru/articles/137608/
#
#                                                  text           title date  \
# 17                          Ошибка доступа к странице  !!! ОШИБКА !!!  NaN
# 27                          Ошибка доступа к странице  !!! ОШИБКА !!!  NaN
# 48  Ошибка парсинга страницы\n'NoneType' object ha...  !!! ОШИБКА !!!  NaN
# 51  Ошибка парсинга страницы\n'NoneType' object ha...  !!! ОШИБКА !!!  NaN
# 71                          Ошибка доступа к странице  !!! ОШИБКА !!!  NaN
#
#     like
# 17   NaN
# 27   NaN
# 48   NaN
# 51   NaN
# 71   NaN
