# %% [markdown]
# ## Задание 1
# Печатные газеты использовали свой формат дат для каждого выпуска. Для каждой газеты из списка напишите формат указанной даты для перевода в объект datetime:
# - The Moscow Times — Wednesday, October 2, 2002
# - The Guardian — Friday, 11.10.13
# - Daily News — Thursday, 18 August 1977

# %%
from datetime import datetime, timedelta

# %%
dt_mt = datetime.strptime('Wednesday, October 2, 2002', '%A, %B %d, %Y')
dt_g =  datetime.strptime('Friday, 11.10.13', '%A, %d.%m.%y')
dt_dn = datetime.strptime('Thursday, 18 August 1977', '%A, %d %B %Y')
dt_mt, dt_g, dt_dn
# Out:
# (datetime.datetime(2002, 10, 2, 0, 0),
#  datetime.datetime(2013, 10, 11, 0, 0),
#  datetime.datetime(1977, 8, 18, 0, 0))

# %% [markdown]
# ## Задание 2
# Дан поток дат в формате YYYY-MM-DD, в которых встречаются некорректные значения:
#
# `stream = [‘2018-04-02’, ‘2018-02-29’, ‘2018-19-02’]`
#
# Напишите функцию, которая проверяет эти даты на корректность. То есть для каждой даты возвращает True — дата корректна или False — некорректная.

# %%
def check_date(dt_str):
  try:
    _ = datetime.strptime(dt_str, '%Y-%m-%d')
    return True
  except:
    return False

stream = ['2018-04-02', '2018-02-29', '2018-19-02']

list(map(check_date, stream))
# Out:
# [True, False, False]

# %% [markdown]
# ## Задание 3
# Напишите функцию date_range, которая возвращает список дат за период от start_date до end_date.
#
# Даты должны вводиться в формате YYYY-MM-DD.
#
# В случае неверного формата или при start_date > end_date должен возвращаться пустой список.

# %%
def date_range(start_date, end_date):
  try:
    s_date = datetime.fromisoformat(start_date)
    e_date = datetime.fromisoformat(end_date)
  except:
    return []
  dates = []
  while s_date <= e_date:
    dates.append(s_date)
    s_date += timedelta(days=1)
  return dates

print(date_range('2023-10-10', '2023-10-12'))
print(date_range('2023-10-15', '2023-10-12'))
print(date_range('2023-13-10', '2023-10-12'))
# Out:
# [datetime.datetime(2023, 10, 10, 0, 0), datetime.datetime(2023, 10, 11, 0, 0), datetime.datetime(2023, 10, 12, 0, 0)]
# []
# []

# %% [markdown]
# # Задание 4

# %%
DEFAULT_USER_COUNT = 3

def delete_and_return_last_user(region, default_list=['A100', 'A101', 'A102']):
  '''
  Удаляет из списка default_list последнего пользователя
  и возвращает ID нового последнего пользователя.
  '''

  element_to_delete = default_list[-1]
  default_list.remove(element_to_delete)

  return default_list[DEFAULT_USER_COUNT-2]

# %%
delete_and_return_last_user(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-bfb6c4f8c48e> in <cell line: 1>()
# ----> 1 delete_and_return_last_user(1)
#
# <ipython-input-15-562ec83c4ecc> in delete_and_return_last_user(region, default_list)
#      10   default_list.remove(element_to_delete)
#      11
# ---> 12   return default_list[DEFAULT_USER_COUNT-2]
#
# IndexError: list index out of range

# %% [markdown]
# Задание:
#
# 1. Что значит ошибка list index out of range?
#
# Значит, что элемента с указанным индексом нет в списке. Сам список меньше.
#
# 2. Почему при первом запуске функция работает корректно, а при втором — нет?
#
# Некорректно задается список в параметре по умолчанию. Он создается 1 раз при инициализации функции. И очень быстро заканчивается
