# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import root_mean_squared_error

# %%
movies = pd.read_csv('seminar/movies.csv')
ratings = pd.read_csv('seminar/ratings.csv')
tags = pd.read_csv('seminar/tags.csv')

# %%
movies
# Out:
#       movieId  ...                                       genres
# 0           1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1           2  ...                   Adventure|Children|Fantasy
# 2           3  ...                               Comedy|Romance
# 3           4  ...                         Comedy|Drama|Romance
# 4           5  ...                                       Comedy
# ...       ...  ...                                          ...
# 9737   193581  ...              Action|Animation|Comedy|Fantasy
# 9738   193583  ...                     Animation|Comedy|Fantasy
# 9739   193585  ...                                        Drama
# 9740   193587  ...                             Action|Animation
# 9741   193609  ...                                       Comedy
#
# [9742 rows x 3 columns]

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
# Выделяем год
def year(name):
    try:
        return int(re.findall(r'\d{4}', name)[0])
    except:
        return 0

movies['year'] = movies['title'].apply(year)

# %%
# Добавляем теги
movies['tags'] = tags.groupby('movieId')['tag'].apply(lambda x: '|'.join(list(x)))
movies['tags'].fillna('', inplace=True)

# %%
# Формируем описание
movies['description'] = movies['genres'].replace('-', '') + '|' + movies['tags']

# %%
movies
# Out:
#       movieId  ...                                        description
# 0           1  ...       Adventure|Animation|Children|Comedy|Fantasy|
# 1           2  ...         Adventure|Children|Fantasy|pixar|pixar|fun
# 2           3  ...  Comedy|Romance|fantasy|magic board game|Robin ...
# 3           4  ...                     Comedy|Drama|Romance|moldy|old
# 4           5  ...                                            Comedy|
# ...       ...  ...                                                ...
# 9737   193581  ...                   Action|Animation|Comedy|Fantasy|
# 9738   193583  ...                          Animation|Comedy|Fantasy|
# 9739   193585  ...                                             Drama|
# 9740   193587  ...                                  Action|Animation|
# 9741   193609  ...                                            Comedy|
#
# [9742 rows x 6 columns]

# %%
tfidf = TfidfVectorizer()
descr_tfidf = tfidf.fit_transform(movies['description'])
descr_tfidf
# Out:
# <9742x1343 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26828 stored elements in Compressed Sparse Row format>

# %%
movies.drop(['genres', 'tags', 'description'], axis=1, inplace=True)

# %%
movies = movies.merge(
    pd.DataFrame(descr_tfidf.toarray(), columns=tfidf.get_feature_names_out()),
     how='left',
     left_index=True,
     right_index=True
)

# %%
# Выборку корректно разделять по временной отметке, что бы поздние оценки не влияли на результат
test_size = 0.2

split_index = int(len(ratings) * (1 - test_size))

# %%
movies = movies.merge(
    ratings.sort_values('timestamp')[:split_index].groupby('movieId')['rating'].mean(),
    how='left',
    on='movieId'
)

# %%
movies['rating'].fillna(0, inplace=True)
movies.rename(columns={'rating': 'film_rating'}, inplace=True)

# %%
movies
# Out:
#       movieId                                      title  ...  zombies  film_rating
# 0           1                           Toy Story (1995)  ...      0.0     3.923913
# 1           2                             Jumanji (1995)  ...      0.0     3.400000
# 2           3                    Grumpier Old Men (1995)  ...      0.0     3.294118
# 3           4                   Waiting to Exhale (1995)  ...      0.0     2.357143
# 4           5         Father of the Bride Part II (1995)  ...      0.0     3.063830
# ...       ...                                        ...  ...      ...          ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)  ...      0.0     0.000000
# 9738   193583               No Game No Life: Zero (2017)  ...      0.0     0.000000
# 9739   193585                               Flint (2017)  ...      0.0     0.000000
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)  ...      0.0     0.000000
# ...

# %%
users = ratings.sort_values('timestamp')[:split_index].groupby('userId')['rating'].mean().reset_index()
users['rating'].fillna(0, inplace=True)
users.rename(columns={'rating': 'user_rating'}, inplace=True)
users
# Out:
#      userId  user_rating
# 0         1     4.366379
# 1         2     3.948276
# 2         3     2.435897
# 3         4     3.555556
# 4         5     3.636364
# ..      ...          ...
# 517     605     3.210407
# 518     606     3.657399
# 519     607     3.786096
# 520     608     3.134176
# 521     609     3.270270
#
# [522 rows x 2 columns]

# %%
ratings.merge(
     movies,
     how='inner',
     on='movieId'
)
# Out:
#         userId  movieId  rating  ...  zombie zombies  film_rating
# 0            1        1     4.0  ...     0.0     0.0     3.923913
# 1            5        1     4.0  ...     0.0     0.0     3.923913
# 2            7        1     4.5  ...     0.0     0.0     3.923913
# 3           15        1     2.5  ...     0.0     0.0     3.923913
# 4           17        1     4.5  ...     0.0     0.0     3.923913
# ...        ...      ...     ...  ...     ...     ...          ...
# 100831     610   160341     2.5  ...     0.0     0.0     0.000000
# 100832     610   160527     4.5  ...     0.0     0.0     0.000000
# 100833     610   160836     3.0  ...     0.0     0.0     0.000000
# 100834     610   163937     3.5  ...     0.0     0.0     0.000000
# 100835     610   163981     3.5  ...     0.0     0.0     0.000000
#
# [100836 rows x 1350 columns]

# %%
df = ratings.merge(
    movies,
    how='inner',
    on='movieId'
).merge(
    users, 
    how='left', 
    on='userId'
)

# %%
df['user_rating'].fillna(0, inplace=True)
df
# Out:
#         userId  movieId  rating  ...  zombies film_rating  user_rating
# 0            1        1     4.0  ...      0.0    3.923913     4.366379
# 1            5        1     4.0  ...      0.0    3.923913     3.636364
# 2            7        1     4.5  ...      0.0    3.923913     3.230263
# 3           15        1     2.5  ...      0.0    3.923913     2.843750
# 4           17        1     4.5  ...      0.0    3.923913     4.209524
# ...        ...      ...     ...  ...      ...         ...          ...
# 100831     610   160341     2.5  ...      0.0    0.000000     0.000000
# 100832     610   160527     4.5  ...      0.0    0.000000     0.000000
# 100833     610   160836     3.0  ...      0.0    0.000000     0.000000
# 100834     610   163937     3.5  ...      0.0    0.000000     0.000000
# 100835     610   163981     3.5  ...      0.0    0.000000     0.000000
#
# [100836 rows x 1351 columns]

# %%
X = df.drop(['userId', 'movieId', 'timestamp', 'rating', 'title'], axis=1)
y = df['rating']

# %%
X_train = X[:split_index]
X_test = X[split_index:]
y_train = y[:split_index]
y_test = y[split_index:]

# %%
nr = KNeighborsRegressor().fit(X_train, y_train)
y_pred = nr.predict(X_test)

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# 0.9552208884108877

# %% [markdown]
# Не очень большая точность получилась в итоге. +- 1 балл
